# %% [markdown]
# This notebook contains the implementation of the models to:
#
# - Make boundary boxes
# - Crop the images
#     - Store the cropped images in a folder, with the name of the shelf_image. All the cropped images should be there
# - Try to eliminate the non-product images
#
# Models:
#
# - YOLOv11.n (10MB)
# - YOLOv5 (148MB)

# %%
# Dependencies and Packages:

# !pip install ultralytics
# from google.colab import drive
# drive.mount('/content/drive')
# !cp "/content/drive/MyDrive/YOLOv5_SKU.pt" /content/
# !git clone https://github.com/warun7/dotslash-repo.git
# !cp "/content/dotslash-repo/YOLOv11_SKU.pt" /content/
# !unzip /content/dotslash-repo/smart_cataloging.zip
# Out:
# Collecting ultralytics
#   Downloading ultralytics-8.3.36-py3-none-any.whl.metadata (35 kB)
# Requirement already satisfied: numpy>=1.23.0 in /usr/local/lib/python3.10/dist-packages (from ultralytics) (1.26.4)
# Requirement already satisfied: matplotlib>=3.3.0 in /usr/local/lib/python3.10/dist-packages (from ultralytics) (3.8.0)
# Requirement already satisfied: opencv-python>=4.6.0 in /usr/local/lib/python3.10/dist-packages (from ultralytics) (4.10.0.84)
# Requirement already satisfied: pillow>=7.1.2 in /usr/local/lib/python3.10/dist-packages (from ultralytics) (11.0.0)
# Requirement already satisfied: pyyaml>=5.3.1 in /usr/local/lib/python3.10/dist-packages (from ultralytics) (6.0.2)
# Requirement already satisfied: requests>=2.23.0 in /usr/local/lib/python3.10/dist-packages (from ultralytics) (2.32.3)
# Requirement already satisfied: scipy>=1.4.1 in /usr/local/lib/python3.10/dist-packages (from ultralytics) (1.13.1)
# Requirement already satisfied: torch>=1.8.0 in /usr/local/lib/python3.10/dist-packages (from ultralytics) (2.5.1+cu121)
# Requirement already satisfied: torchvision>=0.9.0 in /usr/local/lib/python3.10/dist-packages (from ultralytics) (0.20.1+cu121)
# Requirement already satisfied: tqdm>=4.64.0 in /usr/local/lib/python3.10/dist-packages (from ultralytics) (4.66.6)
# Requirement already satisfied: psutil in /usr/local/lib/python3.10/dist-packages (from ultralytics) (5.9.5)
# Requirement already satisfied: py-cpuinfo in /usr/local/lib/python3.10/dist-packages (from ultralytics) (9.0.0)
# Requirement already satisfied: pandas>=1.1.4 in /usr/local/lib/python3.10/dist-packages (from ultralytics) (2.2.2)
# Requirement already satisfied: seaborn>=0.11.0 in /usr/local/lib/python3.10/dist-packages (from ultralytics) (0.13.2)
# Collecting ultralytics-thop>=2.0.0 (from ultralytics)
#   Downloading ultralytics_thop-2.0.12-py3-none-any.whl.metadata (9.4 kB)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.3.0->ultralytics) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.3.0->ultralytics) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.3.0->ultralytics) (4.55.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.3.0->ultralytics) (1.4.7)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.3.0->ultralytics) (24.2)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.3.0->ultralytics) (3.2.0)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.3.0->ultralytics) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.1.4->ultralytics) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.1.4->ultralytics) (2024.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests>=2.23.0->ultralytics) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests>=2.23.0->ultralytics) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests>=2.23.0->ultralytics) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests>=2.23.0->ultralytics) (2024.8.30)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from torch>=1.8.0->ultralytics) (3.16.1)
# Requirement already satisfied: typing-extensions>=4.8.0 in /usr/local/lib/python3.10/dist-packages (from torch>=1.8.0->ultralytics) (4.12.2)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch>=1.8.0->ultralytics) (3.4.2)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch>=1.8.0->ultralytics) (3.1.4)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from torch>=1.8.0->ultralytics) (2024.10.0)
# Requirement already satisfied: sympy==1.13.1 in /usr/local/lib/python3.10/dist-packages (from torch>=1.8.0->ultralytics) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from sympy==1.13.1->torch>=1.8.0->ultralytics) (1.3.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.7->matplotlib>=3.3.0->ultralytics) (1.16.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch>=1.8.0->ultralytics) (3.0.2)
# Downloading ultralytics-8.3.36-py3-none-any.whl (887 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 887.3/887.3 kB 40.4 MB/s eta 0:00:00
# Downloading ultralytics_thop-2.0.12-py3-none-any.whl (26 kB)
# Installing collected packages: ultralytics-thop, ultralytics
# Successfully installed ultralytics-8.3.36 ultralytics-thop-2.0.12
# Cloning into 'dotslash-repo'...
# remote: Enumerating objects: 634, done.
# remote: Counting objects: 100% (634/634), done.
# remote: Compressing objects: 100% (465/465), done.
# remote: Total 634 (delta 38), reused 623 (delta 36), pack-reused 0 (from 0)
# Receiving objects: 100% (634/634), 56.49 MiB | 16.09 MiB/s, done.
# Resolving deltas: 100% (38/38), done.
# Archive:  /content/dotslash-repo/smart_cataloging.zip
#    creating: smart_cataloging/
#   inflating: __MACOSX/._smart_cataloging
#   inflating: smart_cataloging/store_16.jpeg
#   inflating: __MACOSX/smart_cataloging/._store_16.jpeg
#   inflating: smart_cataloging/store_41.jpeg
#   inflating: __MACOSX/smart_cataloging/._store_41.jpeg
#   inflating: smart_cataloging/store_6.jpeg
#   inflating: __MACOSX/smart_cataloging/._store_6.jpeg
#   inflating: smart_cataloging/store_20.jpeg
#   inflating: __MACOSX/smart_cataloging/._store_20.jpeg
#   inflating: smart_cataloging/store_36.jpeg
#   inflating: __MACOSX/smart_cataloging/._store_36.jpeg
#   inflating: smart_cataloging/store_37.jpeg
#   inflating: __MACOSX/smart_cataloging/._store_37.jpeg
#   inflating: smart_cataloging/store_21.jpeg
#   inflating: __MACOSX/smart_cataloging/._store_21.jpeg
#   inflating: smart_cataloging/store_7.jpeg
#   inflating: __MACOSX/smart_cataloging/._store_7.jpeg
#   inflating: smart_cataloging/store_40.jpeg
#   inflating: __MACOSX/smart_cataloging/._store_40.jpeg
#   inflating: smart_cataloging/store_17.jpeg
#   inflating: __MACOSX/smart_cataloging/._store_17.jpeg
#   inflating: smart_cataloging/store_26.jpeg
#   inflating: __MACOSX/smart_cataloging/._store_26.jpeg
#   inflating: smart_cataloging/store_30.jpeg
#   inflating: __MACOSX/smart_cataloging/._store_30.jpeg
#   inflating: smart_cataloging/store_10.jpeg
#   inflating: __MACOSX/smart_cataloging/._store_10.jpeg
#   inflating: smart_cataloging/store_47.jpeg
#   inflating: __MACOSX/smart_cataloging/._store_47.jpeg
#   inflating: smart_cataloging/store_51.jpeg
#   inflating: __MACOSX/smart_cataloging/._store_51.jpeg
#   inflating: smart_cataloging/store_50.jpeg
#   inflating: __MACOSX/smart_cataloging/._store_50.jpeg
#   inflating: smart_cataloging/store_46.jpeg
#   inflating: __MACOSX/smart_cataloging/._store_46.jpeg
#   inflating: smart_cataloging/store_11.jpeg
#   inflating: __MACOSX/smart_cataloging/._store_11.jpeg
#   inflating: smart_cataloging/store_31.jpeg
#   inflating: __MACOSX/smart_cataloging/._store_31.jpeg
#   inflating: smart_cataloging/store_27.jpeg
#   inflating: __MACOSX/smart_cataloging/._store_27.jpeg
#   inflating: smart_cataloging/store_1.jpeg
#   inflating: __MACOSX/smart_cataloging/._store_1.jpeg
#   inflating: smart_cataloging/store_32.jpeg
#   inflating: __MACOSX/smart_cataloging/._store_32.jpeg
#   inflating: smart_cataloging/store_24.jpeg
#   inflating: __MACOSX/smart_cataloging/._store_24.jpeg
#   inflating: smart_cataloging/store_2.jpeg
#   inflating: __MACOSX/smart_cataloging/._store_2.jpeg
#   inflating: smart_cataloging/store_49.jpeg
#   inflating: __MACOSX/smart_cataloging/._store_49.jpeg
#   inflating: smart_cataloging/store_28.jpeg
#   inflating: __MACOSX/smart_cataloging/._store_28.jpeg
#   inflating: smart_cataloging/store_45.jpeg
#   inflating: __MACOSX/smart_cataloging/._store_45.jpeg
#   inflating: smart_cataloging/store_12.jpeg
#   inflating: __MACOSX/smart_cataloging/._store_12.jpeg
#   inflating: smart_cataloging/store_13.jpeg
#   inflating: __MACOSX/smart_cataloging/._store_13.jpeg
#   inflating: smart_cataloging/store_44.jpeg
#   inflating: __MACOSX/smart_cataloging/._store_44.jpeg
#   inflating: smart_cataloging/store_52.jpeg
#   inflating: __MACOSX/smart_cataloging/._store_52.jpeg
#   inflating: smart_cataloging/store_29.jpeg
#   inflating: __MACOSX/smart_cataloging/._store_29.jpeg
#   inflating: smart_cataloging/store_48.jpeg
#   inflating: __MACOSX/smart_cataloging/._store_48.jpeg
#   inflating: smart_cataloging/store_3.jpeg
#   inflating: __MACOSX/smart_cataloging/._store_3.jpeg
#   inflating: smart_cataloging/store_25.jpeg
#   inflating: __MACOSX/smart_cataloging/._store_25.jpeg
#   inflating: smart_cataloging/store_33.jpeg
#   inflating: __MACOSX/smart_cataloging/._store_33.jpeg
#   inflating: smart_cataloging/store_38.jpeg
#   inflating: __MACOSX/smart_cataloging/._store_38.jpeg
#   inflating: smart_cataloging/store_43.jpeg
#   inflating: __MACOSX/smart_cataloging/._store_43.jpeg
#   inflating: smart_cataloging/store_8.jpeg
#   inflating: __MACOSX/smart_cataloging/._store_8.jpeg
#   inflating: smart_cataloging/store_14.jpeg
#   inflating: __MACOSX/smart_cataloging/._store_14.jpeg
#   inflating: smart_cataloging/store_34.jpeg
#   inflating: __MACOSX/smart_cataloging/._store_34.jpeg
#   inflating: smart_cataloging/store_22.jpeg
#   inflating: __MACOSX/smart_cataloging/._store_22.jpeg
#   inflating: smart_cataloging/store_4.jpeg
#   inflating: __MACOSX/smart_cataloging/._store_4.jpeg
#   inflating: smart_cataloging/store_18.jpeg
#   inflating: __MACOSX/smart_cataloging/._store_18.jpeg
#   inflating: smart_cataloging/store_19.jpeg
#   inflating: __MACOSX/smart_cataloging/._store_19.jpeg
#   inflating: smart_cataloging/store_5.jpeg
#   inflating: __MACOSX/smart_cataloging/._store_5.jpeg
#   inflating: smart_cataloging/store_23.jpeg
#   inflating: __MACOSX/smart_cataloging/._store_23.jpeg
#   inflating: smart_cataloging/store_35.jpeg
#   inflating: __MACOSX/smart_cataloging/._store_35.jpeg
#   inflating: smart_cataloging/store_15.jpeg
#   inflating: __MACOSX/smart_cataloging/._store_15.jpeg
#   inflating: smart_cataloging/store_9.jpeg
#   inflating: __MACOSX/smart_cataloging/._store_9.jpeg
#   inflating: smart_cataloging/store_42.jpeg
#   inflating: __MACOSX/smart_cataloging/._store_42.jpeg
#   inflating: smart_cataloging/store_39.jpeg
#   inflating: __MACOSX/smart_cataloging/._store_39.jpeg

# %%
## Importing the models

import torch
import ultralytics
from ultralytics import YOLO
# Out:
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.

# %%
import os
import numpy as np
from PIL import Image
from pathlib import Path
import cv2
from ultralytics import YOLO  # For YOLOv11

class YOLOv11Detector:
    def __init__(self, weights_path, base_output_dir):
        """
        Initialize YOLOv11 detector

        Args:
            weights_path (str): Path to YOLOv11 weights
            base_output_dir (str): Base directory for outputs
        """
        self.model = self._load_model(weights_path)
        self.base_output_dir = base_output_dir
        os.makedirs(base_output_dir, exist_ok=True)

    def _load_model(self, weights_path):
        """Load YOLOv11 model with specified weights"""
        model = YOLO(weights_path)
        model.conf = 0.25  # confidence threshold
        model.iou = 0.45   # NMS IoU threshold
        return model

    def create_output_directory(self, image_name):
        """Create output directory structure for an image"""
        image_dir = os.path.join(self.base_output_dir, image_name)
        os.makedirs(image_dir, exist_ok=True)
        return image_dir

    def draw_boxes(self, image, detections):
        """Draw bounding boxes on image"""
        img = np.array(image)

        # Get detections
        boxes = detections.boxes.data.cpu().numpy()

        for box in boxes:
            x1, y1, x2, y2 = map(int, box[:4])
            conf = box[4]

            # Draw rectangle
            cv2.rectangle(img, (x1, y1), (x2, y2), (0, 255, 0), 2)

            # Add confidence score
            conf_text = f'{conf:.2f}'
            cv2.putText(img, conf_text, (x1, y1-10),
                       cv2.FONT_HERSHEY_SIMPLEX, 0.5, (0, 255, 0), 2)

        return Image.fromarray(img)

    def crop_detections(self, image, detections, output_dir, image_name):
        """Crop and save detected products"""
        saved_paths = []

        # Get detections
        boxes = detections.boxes.data.cpu().numpy()

        for i, box in enumerate(boxes):
            x1, y1, x2, y2 = map(int, box[:4])

            # Crop detection
            cropped = image.crop((x1, y1, x2, y2))

            # Save cropped image
            save_path = os.path.join(output_dir, f"{image_name}_P_{i+1}.jpg")
            cropped.save(save_path)
            saved_paths.append(save_path)

        return saved_paths

    def filter_non_products(self, image_path, min_size=50, aspect_ratio_range=(0.5, 2.0)):
        """Filter out likely non-product images"""
        img = Image.open(image_path)
        width, height = img.size

        if width < min_size or height < min_size:
            return False

        aspect_ratio = width / height
        if not (aspect_ratio_range[0] <= aspect_ratio <= aspect_ratio_range[1]):
            return False

        return True

    def process_image(self, image_path):
        """Process single image with YOLOv11"""
        # Load image
        image = Image.open(image_path)
        image_name = Path(image_path).stem

        print(f"Processing {image_name}...")

        # Create output directory
        output_dir = self.create_output_directory(image_name)

        # Detect products
        detections = self.model(image)[0]

        # Save image with bounding boxes
        bb_image = self.draw_boxes(image, detections)
        bb_path = os.path.join(output_dir, f"{image_name}_BB.jpg")
        bb_image.save(bb_path)

        # Crop and save individual products
        cropped_paths = self.crop_detections(image, detections, output_dir, image_name)

        # # Filter non-products
        # for path in cropped_paths:
        #     if not self.filter_non_products(path):
        #         os.remove(path)
        #         print(f"Removed likely non-product: {path}")

        print(f"Finished processing {image_name}")
        print(f"Detected {len(cropped_paths)} products")

    def process_directory(self, input_dir):
        """Process all images in directory"""
        total_images = len([f for f in os.listdir(input_dir)
                          if f.lower().endswith(('.jpg', '.jpeg'))])
        processed = 0

        print(f"Found {total_images} images to process")

        for image_file in os.listdir(input_dir):
            if image_file.lower().endswith(('.jpg', '.jpeg')):
                image_path = os.path.join(input_dir, image_file)
                self.process_image(image_path)
                processed += 1
                print(f"Progress: {processed}/{total_images} images processed")

def main():
    # Configuration
    input_dir = "/content/smart_cataloging"
    base_output_dir = "YOLOv11_results"
    yolov11_weights = "/content/YOLOv11_SKU.pt"

    # Initialize detector
    detector = YOLOv11Detector(
        weights_path=yolov11_weights,
        base_output_dir=base_output_dir
    )

    # Process all images
    detector.process_directory(input_dir)

if __name__ == "__main__":
    main()
# Out:
# Found 52 images to process
# Processing store_22...
#
# 0: 640x480 175 objects, 46.6ms
# Speed: 35.2ms preprocess, 46.6ms inference, 751.4ms postprocess per image at shape (1, 3, 640, 480)
# Finished processing store_22
# Detected 175 products
# Progress: 1/52 images processed
# Processing store_26...
#
# 0: 640x480 93 objects, 9.7ms
# Speed: 2.5ms preprocess, 9.7ms inference, 1.6ms postprocess per image at shape (1, 3, 640, 480)
# Finished processing store_26
# Detected 93 products
# Progress: 2/52 images processed
# Processing store_18...
#
# 0: 640x480 17 objects, 9.7ms
# Speed: 2.8ms preprocess, 9.7ms inference, 1.5ms postprocess per image at shape (1, 3, 640, 480)
# Finished processing store_18
# Detected 17 products
# Progress: 3/52 images processed
# Processing store_47...
#
# 0: 640x480 110 objects, 9.6ms
# Speed: 2.7ms preprocess, 9.6ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 480)
# Finished processing store_47
# Detected 110 products
# Progress: 4/52 images processed
# Processing store_34...
#
# 0: 480x640 64 objects, 47.5ms
# Speed: 2.5ms preprocess, 47.5ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 640)
# Finished processing store_34
# Detected 64 products
# Progress: 5/52 images processed
# Processing store_40...
#
# 0: 384x640 111 objects, 113.8ms
# Speed: 2.2ms preprocess, 113.8ms inference, 2.7ms postprocess per image at shape (1, 3, 384, 640)
# Finished processing store_40
# Detected 111 products
# Progress: 6/52 images processed
# Processing store_11...
#
# 0: 640x480 105 objects, 11.6ms
# Speed: 2.0ms preprocess, 11.6ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 480)
# Finished processing store_11
# Detected 105 products
# Progress: 7/52 images processed
# Processing store_28...
#
# 0: 640x480 105 objects, 10.0ms
# Speed: 2.7ms preprocess, 10.0ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 480)
# Finished processing store_28
# Detected 105 products
# Progress: 8/52 images processed
# Processing store_7...
#
# 0: 288x640 74 objects, 48.7ms
# Speed: 1.8ms preprocess, 48.7ms inference, 2.6ms postprocess per image at shape (1, 3, 288, 640)
# Finished processing store_7
# Detected 74 products
# Progress: 9/52 images processed
# Processing store_8...
#
# 0: 288x640 63 objects, 10.3ms
# Speed: 1.7ms preprocess, 10.3ms inference, 1.4ms postprocess per image at shape (1, 3, 288, 640)
# Finished processing store_8
# Detected 63 products
# Progress: 10/52 images processed
# Processing store_5...
#
# 0: 288x640 119 objects, 9.7ms
# Speed: 1.8ms preprocess, 9.7ms inference, 1.4ms postprocess per image at shape (1, 3, 288, 640)
# Finished processing store_5
# Detected 119 products
# Progress: 11/52 images processed
# Processing store_33...
#
# 0: 640x480 35 objects, 10.5ms
# Speed: 2.6ms preprocess, 10.5ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 480)
# Finished processing store_33
# Detected 35 products
# Progress: 12/52 images processed
# Processing store_36...
#
# 0: 640x480 67 objects, 9.9ms
# Speed: 2.7ms preprocess, 9.9ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 480)
# Finished processing store_36
# Detected 67 products
# Progress: 13/52 images processed
# Processing store_9...
#
# 0: 288x640 3 objects, 10.7ms
# Speed: 1.8ms preprocess, 10.7ms inference, 3.4ms postprocess per image at shape (1, 3, 288, 640)
# Finished processing store_9
# Detected 3 products
# Progress: 14/52 images processed
# Processing store_13...
#
# 0: 480x640 120 objects, 11.1ms
# Speed: 2.2ms preprocess, 11.1ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 640)
# Finished processing store_13
# Detected 120 products
# Progress: 15/52 images processed
# Processing store_12...
#
# 0: 480x640 125 objects, 14.0ms
# Speed: 3.0ms preprocess, 14.0ms inference, 2.1ms postprocess per image at shape (1, 3, 480, 640)
# Finished processing store_12
# Detected 125 products
# Progress: 16/52 images processed
# Processing store_27...
#
# 0: 640x480 150 objects, 10.8ms
# Speed: 3.1ms preprocess, 10.8ms inference, 1.5ms postprocess per image at shape (1, 3, 640, 480)
# Finished processing store_27
# Detected 150 products
# Progress: 17/52 images processed
# Processing store_30...
#
# 0: 640x480 150 objects, 10.3ms
# Speed: 2.8ms preprocess, 10.3ms inference, 1.9ms postprocess per image at shape (1, 3, 640, 480)
# Finished processing store_30
# Detected 150 products
# Progress: 18/52 images processed
# Processing store_25...
#
# 0: 640x480 69 objects, 15.2ms
# Speed: 2.8ms preprocess, 15.2ms inference, 2.5ms postprocess per image at shape (1, 3, 640, 480)
# Finished processing store_25
# Detected 69 products
# Progress: 19/52 images processed
# Processing store_10...
#
# 0: 288x640 6 objects, 17.0ms
# Speed: 2.9ms preprocess, 17.0ms inference, 4.8ms postprocess per image at shape (1, 3, 288, 640)
# Finished processing store_10
# Detected 6 products
# Progress: 20/52 images processed
# Processing store_15...
#
# 0: 480x640 97 objects, 13.9ms
# Speed: 2.7ms preprocess, 13.9ms inference, 1.7ms postprocess per image at shape (1, 3, 480, 640)
# Finished processing store_15
# Detected 97 products
# Progress: 21/52 images processed
# Processing store_39...
#
# 0: 384x640 46 objects, 14.2ms
# Speed: 2.4ms preprocess, 14.2ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
# Finished processing store_39
# Detected 46 products
# Progress: 22/52 images processed
# Processing store_52...
#
# 0: 480x640 33 objects, 23.3ms
# Speed: 6.0ms preprocess, 23.3ms inference, 2.7ms postprocess per image at shape (1, 3, 480, 640)
# Finished processing store_52
# Detected 33 products
# Progress: 23/52 images processed
# Processing store_6...
#
# 0: 480x640 115 objects, 12.1ms
# Speed: 4.7ms preprocess, 12.1ms inference, 1.9ms postprocess per image at shape (1, 3, 480, 640)
# Finished processing store_6
# Detected 115 products
# Progress: 24/52 images processed
# Processing store_3...
#
# 0: 480x640 29 objects, 13.1ms
# Speed: 4.8ms preprocess, 13.1ms inference, 3.1ms postprocess per image at shape (1, 3, 480, 640)
# Finished processing store_3
# Detected 29 products
# Progress: 25/52 images processed
# Processing store_17...
#
# 0: 640x480 75 objects, 13.2ms
# Speed: 5.6ms preprocess, 13.2ms inference, 1.7ms postprocess per image at shape (1, 3, 640, 480)
# Finished processing store_17
# Detected 75 products
# Progress: 26/52 images processed
# Processing store_42...
#
# 0: 384x640 59 objects, 15.9ms
# Speed: 3.3ms preprocess, 15.9ms inference, 4.6ms postprocess per image at shape (1, 3, 384, 640)
# Finished processing store_42
# Detected 59 products
# Progress: 27/52 images processed
# Processing store_2...
#
# 0: 480x640 81 objects, 16.8ms
# Speed: 4.5ms preprocess, 16.8ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
# Finished processing store_2
# Detected 81 products
# Progress: 28/52 images processed
# Processing store_43...
#
# 0: 640x480 85 objects, 18.2ms
# Speed: 4.3ms preprocess, 18.2ms inference, 1.9ms postprocess per image at shape (1, 3, 640, 480)
# Finished processing store_43
# Detected 85 products
# Progress: 29/52 images processed
# Processing store_31...
#
# 0: 640x480 83 objects, 16.5ms
# Speed: 4.5ms preprocess, 16.5ms inference, 3.2ms postprocess per image at shape (1, 3, 640, 480)
# Finished processing store_31
# Detected 83 products
# Progress: 30/52 images processed
# Processing store_29...
#
# 0: 640x480 48 objects, 16.4ms
# Speed: 4.5ms preprocess, 16.4ms inference, 2.2ms postprocess per image at shape (1, 3, 640, 480)
# Finished processing store_29
# Detected 48 products
# Progress: 31/52 images processed
# Processing store_38...
#
# 0: 640x480 121 objects, 16.2ms
# Speed: 4.4ms preprocess, 16.2ms inference, 2.2ms postprocess per image at shape (1, 3, 640, 480)
# Finished processing store_38
# Detected 121 products
# Progress: 32/52 images processed
# Processing store_1...
#
# 0: 480x640 64 objects, 17.0ms
# Speed: 4.4ms preprocess, 17.0ms inference, 4.2ms postprocess per image at shape (1, 3, 480, 640)
# Finished processing store_1
# Detected 64 products
# Progress: 33/52 images processed
# Processing store_49...
#
# 0: 480x640 104 objects, 17.0ms
# Speed: 4.5ms preprocess, 17.0ms inference, 2.1ms postprocess per image at shape (1, 3, 480, 640)
# Finished processing store_49
# Detected 104 products
# Progress: 34/52 images processed
# Processing store_4...
#
# 0: 480x640 54 objects, 18.1ms
# Speed: 4.8ms preprocess, 18.1ms inference, 4.2ms postprocess per image at shape (1, 3, 480, 640)
# Finished processing store_4
# Detected 54 products
# Progress: 35/52 images processed
# Processing store_48...
#
# 0: 640x480 89 objects, 10.7ms
# Speed: 2.8ms preprocess, 10.7ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 480)
# Finished processing store_48
# Detected 89 products
# Progress: 36/52 images processed
# Processing store_44...
#
# 0: 640x480 81 objects, 9.9ms
# Speed: 2.9ms preprocess, 9.9ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 480)
# Finished processing store_44
# Detected 81 products
# Progress: 37/52 images processed
# Processing store_24...
#
# 0: 640x480 300 objects, 9.6ms
# Speed: 2.8ms preprocess, 9.6ms inference, 1.9ms postprocess per image at shape (1, 3, 640, 480)
# Finished processing store_24
# Detected 300 products
# Progress: 38/52 images processed
# Processing store_51...
#
# 0: 480x640 61 objects, 9.9ms
# Speed: 2.7ms preprocess, 9.9ms inference, 1.3ms postprocess per image at shape (1, 3, 480, 640)
# Finished processing store_51
# Detected 61 products
# Progress: 39/52 images processed
# Processing store_41...
#
# 0: 640x480 93 objects, 10.3ms
# Speed: 2.9ms preprocess, 10.3ms inference, 2.2ms postprocess per image at shape (1, 3, 640, 480)
# Finished processing store_41
# Detected 93 products
# Progress: 40/52 images processed
# Processing store_16...
#
# 0: 640x480 10 objects, 9.9ms
# Speed: 2.8ms preprocess, 9.9ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 480)
# Finished processing store_16
# Detected 10 products
# Progress: 41/52 images processed
# Processing store_23...
#
# 0: 480x640 93 objects, 14.5ms
# Speed: 3.4ms preprocess, 14.5ms inference, 1.7ms postprocess per image at shape (1, 3, 480, 640)
# Finished processing store_23
# Detected 93 products
# Progress: 42/52 images processed
# Processing store_37...
#
# 0: 640x480 67 objects, 10.7ms
# Speed: 2.8ms preprocess, 10.7ms inference, 2.3ms postprocess per image at shape (1, 3, 640, 480)
# Finished processing store_37
# Detected 67 products
# Progress: 43/52 images processed
# Processing store_46...
#
# 0: 640x480 61 objects, 9.5ms
# Speed: 2.6ms preprocess, 9.5ms inference, 1.5ms postprocess per image at shape (1, 3, 640, 480)
# Finished processing store_46
# Detected 61 products
# Progress: 44/52 images processed
# Processing store_14...
#
# 0: 288x640 59 objects, 11.1ms
# Speed: 1.7ms preprocess, 11.1ms inference, 1.4ms postprocess per image at shape (1, 3, 288, 640)
# Finished processing store_14
# Detected 59 products
# Progress: 45/52 images processed
# Processing store_20...
#
# 0: 640x480 35 objects, 10.2ms
# Speed: 2.7ms preprocess, 10.2ms inference, 1.5ms postprocess per image at shape (1, 3, 640, 480)
# Finished processing store_20
# Detected 35 products
# Progress: 46/52 images processed
# Processing store_19...
#
# 0: 640x480 51 objects, 13.8ms
# Speed: 4.7ms preprocess, 13.8ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 480)
# Finished processing store_19
# Detected 51 products
# Progress: 47/52 images processed
# Processing store_50...
#
# 0: 480x640 116 objects, 11.0ms
# Speed: 2.8ms preprocess, 11.0ms inference, 2.4ms postprocess per image at shape (1, 3, 480, 640)
# Finished processing store_50
# Detected 116 products
# Progress: 48/52 images processed
# Processing store_45...
#
# 0: 480x640 80 objects, 10.6ms
# Speed: 2.7ms preprocess, 10.6ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 640)
# Finished processing store_45
# Detected 80 products
# Progress: 49/52 images processed
# Processing store_35...
#
# 0: 640x480 105 objects, 16.3ms
# Speed: 4.6ms preprocess, 16.3ms inference, 1.8ms postprocess per image at shape (1, 3, 640, 480)
# Finished processing store_35
# Detected 105 products
# Progress: 50/52 images processed
# Processing store_32...
#
# 0: 640x480 88 objects, 9.8ms
# Speed: 2.8ms preprocess, 9.8ms inference, 1.6ms postprocess per image at shape (1, 3, 640, 480)
# Finished processing store_32
# Detected 88 products
# Progress: 51/52 images processed
# Processing store_21...
#
# 0: 640x480 161 objects, 9.8ms
# Speed: 2.7ms preprocess, 9.8ms inference, 1.9ms postprocess per image at shape (1, 3, 640, 480)
# Finished processing store_21
# Detected 161 products
# Progress: 52/52 images processed

# %%
# !zip YOLOv11_results_all -r /content/YOLOv11_results
# Out:
#   adding: content/YOLOv11_results/ (stored 0%)
#   adding: content/YOLOv11_results/store_6/ (stored 0%)
#   adding: content/YOLOv11_results/store_6/store_6_P_26.jpg (deflated 12%)
#   adding: content/YOLOv11_results/store_6/store_6_P_55.jpg (deflated 9%)
#   adding: content/YOLOv11_results/store_6/store_6_P_68.jpg (deflated 5%)
#   adding: content/YOLOv11_results/store_6/store_6_P_56.jpg (deflated 15%)
#   adding: content/YOLOv11_results/store_6/store_6_P_92.jpg (deflated 10%)
#   adding: content/YOLOv11_results/store_6/store_6_P_104.jpg (deflated 6%)
#   adding: content/YOLOv11_results/store_6/store_6_P_66.jpg (deflated 16%)
#   adding: content/YOLOv11_results/store_6/store_6_P_29.jpg (deflated 9%)
#   adding: content/YOLOv11_results/store_6/store_6_P
jpg (deflated 3%)
#   adding: content/YOLOv11_results/store_27/store_27_P_126.jpg (deflated 9%)
#   adding: content/YOLOv11_results/store_29/ (stored 0%)
#   adding: content/YOLOv11_results/store_29/store_29_P_1.jpg (deflated 2%)
#   adding: content/YOLOv11_results/store_29/store_29_P_13.jpg (deflated 3%)
#   adding: content/YOLOv11_results/store_29/store_29_P_33.jpg (deflated 2%)
#   adding: content/YOLOv11_results/store_29/store_29_P_8.jpg (deflated 6%)
#   adding: content/YOLOv11_results/store_29/store_29_P_34.jpg (deflated 5%)
#   adding: content/YOLOv11_results/store_29/store_29_P_37.jpg (deflated 2%)
#   adding: content/YOLOv11_results/store_29/store_29_P_41.jpg (deflated 2%)
#   adding: content/YOLOv11_results/store_29/store_29_P_18.jpg (deflated 2%)
#   adding: content/YOLOv11_results/store_29/store_29_P_39.jpg (deflated 4%)
#   adding: content/YOLOv11_results/store_29/store_29_P_15.jpg (deflated 2%)
#   adding: content/YOLOv11_results/store_29/store_29_P_16.jpg (deflated 3%)
#   adding: content/YOLOv11_results/store_29/store_29_P_32.jpg (deflated 5%)
#   adding: content/YOLOv11_results/store_29/store_29_P_20.jpg (deflated 5%)
#   adding: content/YOLOv11_results/store_29/store_29_P_5.jpg (deflated 3%)
#   adding: content/YOLOv11_results/store_29/store_29_P_48.jpg (deflated 5%)
#   adding: content/YOLOv11_results/store_29/store_29_P_17.jpg (deflated 2%)
#   adding: content/YOLOv11_results/store_29/store_29_P_21.jpg (deflated 3%)
#   adding: content/YOLOv11_results/store_29/store_29_P_47.jpg (deflated 6%)
#   adding: content/YOLOv11_results/store_29/store_29_P_45.jpg (deflated 2%)
#   adding: content/YOLOv11_results/store_29/store_29_P_46.jpg (deflated 4%)
#   adding: content/YOLOv11_results/store_29/store_29_P_7.jpg (deflated 4%)
#   adding: content/YOLOv11_results/store_29/store_29_P_30.jpg (deflated 3%)
#   adding: content/YOLOv11_results/store_29/store_29_P_4.jpg (deflated 2%)
#   adding: content/YOLOv11_results/store_29/store_29_P_44.jpg (deflated 2%)
#   adding: content/YOLOv11_results/store_29/store_29_P_6.jpg (deflated 3%)
#   adding: content/YOLOv11_results/store_29/store_29_P_22.jpg (deflated 6%)
#   adding: content/YOLOv11_results/store_29/store_29_P_40.jpg (deflated 1%)
#   adding: content/YOLOv11_results/store_29/store_29_P_31.jpg (deflated 4%)
#   adding: content/YOLOv11_results/store_29/store_29_P_11.jpg (deflated 5%)
#   adding: content/YOLOv11_results/store_29/store_29_P_12.jpg (deflated 2%)
#   adding: content/YOLOv11_results/store_29/store_29_P_28.jpg (deflated 2%)
#   adding: content/YOLOv11_results/store_29/store_29_P_38.jpg (deflated 2%)
#   adding: content/YOLOv11_results/store_29/store_29_P_24.jpg (deflated 2%)
#   adding: content/YOLOv11_results/store_29/store_29_BB.jpg (deflated 1%)
#   adding: content/YOLOv11_results/store_29/store_29_P_2.jpg (deflated 4%)
#   adding: content/YOLOv11_results/store_29/store_29_P_35.jpg (deflated 2%)
#   adding: content/YOLOv11_results/store_29/store_29_P_10.jpg (deflated 5%)
#   adding: content/YOLOv11_results/store_29/store_29_P_36.jpg (deflated 2%)
#   adding: content/YOLOv11_results/store_29/store_29_P_19.jpg (deflated 2%)
#   adding: content/YOLOv11_results/store_29/store_29_P_42.jpg (deflated 5%)
#   adding: content/YOLOv11_results/store_29/store_29_P_14.jpg (deflated 5%)
#   adding: content/YOLOv11_results/store_29/store_29_P_29.jpg (deflated 4%)
#   adding: content/YOLOv11_results/store_29/store_29_P_3.jpg (deflated 2%)
#   adding: content/YOLOv11_results/store_29/store_29_P_23.jpg (deflated 5%)
#   adding: content/YOLOv11_results/store_29/store_29_P_27.jpg (deflated 3%)
#   adding: content/YOLOv11_results/store_29/store_29_P_9.jpg (deflated 5%)
#   adding: content/YOLOv11_results/store_29/store_29_P_25.jpg (deflated 5%)
#   adding: content/YOLOv11_results/store_29/store_29_P_43.jpg (deflated 1%)
#   adding: content/YOLOv11_results/store_29/store_29_P_26.jpg (deflated 2%)

# %% [markdown]
# ## Trying OCR:

# %%
# Load model directly
from transformers import AutoProcessor, AutoModelForImageTextToText

processor = AutoProcessor.from_pretrained("huz-relay/idefics2-8b-ocr")
model = AutoModelForImageTextToText.from_pretrained("huz-relay/idefics2-8b-ocr")
# Out:
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# processor_config.json:   0%|          | 0.00/483 [00:00<?, ?B/s]
# Chat templates should be in a 'chat_template.json' file but found key='chat_template' in the processor's config. Make sure to move your template to its own file.
# preprocessor_config.json:   0%|          | 0.00/460 [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/1.64k [00:00<?, ?B/s]
# tokenizer.model:   0%|          | 0.00/493k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/1.80M [00:00<?, ?B/s]
# added_tokens.json:   0%|          | 0.00/92.0 [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/1.04k [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/684 [00:00<?, ?B/s]
# model.safetensors.index.json:   0%|          | 0.00/74.4k [00:00<?, ?B/s]
# Downloading shards:   0%|          | 0/7 [00:00<?, ?it/s]
# model-00001-of-00007.safetensors:   0%|          | 0.00/4.64G [00:00<?, ?B/s]
# model-00002-of-00007.safetensors:   0%|          | 0.00/4.99G [00:00<?, ?B/s]
# model-00003-of-00007.safetensors:   0%|          | 0.00/4.90G [00:00<?, ?B/s]
# model-00004-of-00007.safetensors:   0%|          | 0.00/5.00G [00:00<?, ?B/s]
# model-00005-of-00007.safetensors:   0%|          | 0.00/5.00G [00:00<?, ?B/s]
# model-00006-of-00007.safetensors:   0%|          | 0.00/4.83G [00:00<?, ?B/s]
# model-00007-of-00007.safetensors:   0%|          | 0.00/4.25G [00:00<?, ?B/s]
# Loading checkpoint shards:   0%|          | 0/7 [00:00<?, ?it/s]
# generation_config.json:   0%|          | 0.00/185 [00:00<?, ?B/s]

# %%
print(model)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-a87813ffe34d> in <cell line: 1>()
# ----> 1 print(model)
#
# NameError: name 'model' is not defined

# %%
import torch
from PIL import Image
from transformers import AutoProcessor, AutoModelForImageTextToText

def perform_ocr(image_path, model, processor, prompt="The following is a product image, extract the product name from this image:", max_new_tokens=512):
    """
    Perform OCR on an image using IDEFICS2 model.

    Args:
        image_path (str): Path to the image file
        model: The loaded IDEFICS2 model
        processor: The loaded IDEFICS2 processor
        prompt (str): Prompt to guide the text extraction
        max_new_tokens (int): Maximum number of tokens to generate

    Returns:
        str: Extracted text from the image
    """
    # Load and preprocess the image
    image = Image.open(image_path)

    # Prepare inputs
    inputs = processor(
        prompt,
        images=image,
        return_tensors="pt",
        truncation=True,
        max_length=2048
    )

    # Generate text
    with torch.no_grad():
        outputs = model.generate(
            **inputs,
            max_new_tokens=max_new_tokens,
            do_sample=False
        )

    # Decode the generated text
    generated_text = processor.batch_decode(outputs, skip_special_tokens=True)[0]

    # Remove the prompt from the generated text
    if generated_text.startswith(prompt):
        generated_text = generated_text[len(prompt):].strip()

    return generated_text

# Example usage
if __name__ == "__main__":
    # Load model and processor (you already have this part)
    # processor = AutoProcessor.from_pretrained("huz-relay/idefics2-8b-ocr")
    # model = AutoModelForImageTextToText.from_pretrained("huz-relay/idefics2-8b-ocr")

    # Example usage
    image_path = "/content/YOLOv11_results/store_29/store_29_P_26.jpg"
    extracted_text = perform_ocr(image_path, model, processor)
    print("Extracted text:", extracted_text)

    # Example with custom prompt
    custom_prompt = "The following is a product image, extract the product name from this image"
    extracted_text = perform_ocr(image_path, model, processor, prompt=custom_prompt)
    print("Extracted text with custom prompt:", extracted_text)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-6-7a636fcfc6e8> in <cell line: 49>()
#      54     # Example usage
#      55     image_path = "/content/YOLOv11_results/store_29/store_29_P_26.jpg"
# ---> 56     extracted_text = perform_ocr(image_path, model, processor)
#      57     print("Extracted text:", extracted_text)
#      58
#
# <ipython-input-6-7a636fcfc6e8> in perform_ocr(image_path, model, processor, prompt, max_new_tokens)
#      21
#      22     # Prepare inputs
# ---> 23     inputs = processor(
#      24         prompt,
#      25         images=image,
#
# TypeError: Idefics2Processor.__call__() got multiple values for argument 'images'

# %%
import torch
from PIL import Image
from transformers import AutoProcessor, AutoModelForImageTextToText

def perform_ocr(image_path, model, processor, prompt="Extract all text from this image:", max_new_tokens=512):
    """
    Perform OCR on an image using IDEFICS2 model.

    Args:
        image_path (str): Path to the image file
        model: The loaded IDEFICS2 model
        processor: The loaded IDEFICS2 processor
        prompt (str): Prompt to guide the text extraction
        max_new_tokens (int): Maximum number of tokens to generate

    Returns:
        str: Extracted text from the image
    """
    # Load and preprocess the image
    image = Image.open(image_path)

    # Prepare inputs - format text and images correctly
    inputs = processor(
       text=[prompt],
       images=image,
       return_tensors="pt",
       truncation=True,
       max_length=2048
   )
    # Generate text
    with torch.no_grad():
        outputs = model.generate(
            **inputs,
            max_new_tokens=max_new_tokens,
            do_sample=False
        )

    # Decode the generated text
    generated_text = processor.batch_decode(outputs, skip_special_tokens=True)[0]

    # Remove the prompt from the generated text if it appears at the start
    if generated_text.startswith(prompt):
        generated_text = generated_text[len(prompt):].strip()

    return generated_text

# Example usage
if __name__ == "__main__":
    # Load image and try OCR
    image_path = "/content/Everes_masala.jpg"

    # Different prompts to try
    prompts = [
        "Extract all text from this image:",
        "What text can you read in this image? Extract all text:",
        "Please transcribe all visible text in this image, including any small text:"
    ]

    # Try with default prompt first
    try:
        extracted_text = perform_ocr(image_path, model, processor)
        print("Extracted text:", extracted_text)
    except Exception as e:
        print(f"Error with default prompt: {str(e)}")

    # Try with different prompts
    for prompt in prompts:
        try:
            print(f"\nTrying with prompt: {prompt}")
            extracted_text = perform_ocr(image_path, model, processor, prompt=prompt)
            print("Extracted text:", extracted_text)
        except Exception as e:
            print(f"Error with prompt '{prompt}': {str(e)}")
# Out:
# Error with default prompt: The number of images in the text [0] and images  [1] should be the same.
#
# Trying with prompt: Extract all text from this image:
# Error with prompt 'Extract all text from this image:': The number of images in the text [0] and images  [1] should be the same.
#
# Trying with prompt: What text can you read in this image? Extract all text:
# Error with prompt 'What text can you read in this image? Extract all text:': The number of images in the text [0] and images  [1] should be the same.
#
# Trying with prompt: Please transcribe all visible text in this image, including any small text:
# Error with prompt 'Please transcribe all visible text in this image, including any small text:': The number of images in the text [0] and images  [1] should be the same.

# %%
# !export PYTORCH_CUDA_ALLOC_CONF=expandable_segments:True

# %%
model = model.to("cuda")
# Out:
# ---------------------------------------------------------------------------
# OutOfMemoryError                          Traceback (most recent call last)
# <ipython-input-22-ddb4345499c6> in <cell line: 1>()
# ----> 1 model = model.to("cuda")
#
# /usr/local/lib/python3.10/dist-packages/transformers/modeling_utils.py in to(self, *args, **kwargs)
#    3155                     " `dtype` by passing the correct `torch_dtype` argument."
#    3156                 )
# -> 3157         return super().to(*args, **kwargs)
#    3158
#    3159     def half(self, *args):
#
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/module.py in to(self, *args, **kwargs)
#    1338                     raise
#    1339
# -> 1340         return self._apply(convert)
#    1341
#    1342     def register_full_backward_pre_hook(
#
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/module.py in _apply(self, fn, recurse)
#     898         if recurse:
#     899             for module in self.children():
# --> 900                 module._apply(fn)
#     901
#     902         def compute_should_use_set_data(tensor, tensor_applied):
#
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/module.py in _apply(self, fn, recurse)
#     898         if recurse:
#     899             for module in self.children():
# --> 900                 module._apply(fn)
#     901
#     902         def compute_should_use_set_data(tensor, tensor_applied):
#
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/module.py in _apply(self, fn, recurse)
#     898         if recurse:
#     899             for module in self.children():
# --> 900                 module._apply(fn)
#     901
#     902         def compute_should_use_set_data(tensor, tensor_applied):
#
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/module.py in _apply(self, fn, recurse)
#     898         if recurse:
#     899             for module in self.children():
# --> 900                 module._apply(fn)
#     901
#     902         def compute_should_use_set_data(tensor, tensor_applied):
#
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/module.py in _apply(self, fn, recurse)
#     898         if recurse:
#     899             for module in self.children():
# --> 900                 module._apply(fn)
#     901
#     902         def compute_should_use_set_data(tensor, tensor_applied):
#
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/module.py in _apply(self, fn, recurse)
#     898         if recurse:
#     899             for module in self.children():
# --> 900                 module._apply(fn)
#     901
#     902         def compute_should_use_set_data(tensor, tensor_applied):
#
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/module.py in _apply(self, fn, recurse)
#     925             # `with torch.no_grad():`
#     926             with torch.no_grad():
# --> 927                 param_applied = fn(param)
#     928             p_should_use_set_data = compute_should_use_set_data(param, param_applied)
#     929
#
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/module.py in convert(t)
#    1324                         memory_format=convert_to_format,
#    1325                     )
# -> 1326                 return t.to(
#    1327                     device,
#    1328                     dtype if t.is_floating_point() or t.is_complex() else None,
#
# OutOfMemoryError: CUDA out of memory. Tried to allocate 224.00 MiB. GPU 0 has a total capacity of 14.75 GiB of which 211.06 MiB is free. Process 4277 has 14.54 GiB memory in use. Of the allocated memory 14.16 GiB is allocated by PyTorch, and 236.22 MiB is reserved by PyTorch but unallocated. If reserved but unallocated memory is large try setting PYTORCH_CUDA_ALLOC_CONF=expandable_segments:True to avoid fragmentation.  See documentation for Memory Management  (https://pytorch.org/docs/stable/notes/cuda.html#environment-variables)

# %%
import requests
import torch
from PIL import Image
from io import BytesIO

from transformers import AutoProcessor, AutoModelForVision2Seq
from transformers.image_utils import load_image

# DEVICE = "cuda:0"

# Note that passing the image urls (instead of the actual pil images) to the processor is also possible
image1 = load_image("/content/Everest_SM.jpeg")
image2 = load_image("/content/Everest_PB.jpg")
image3 = load_image("/content/Everes_masala.jpg")

# %%
# processor = AutoProcessor.from_pretrained("HuggingFaceM4/idefics2-8b-base")
# model = AutoModelForVision2Seq.from_pretrained(
#     "HuggingFaceM4/idefics2-8b-base",
# ).to(DEVICE)

# Create inputs
prompts = [
  "The following is a product image, extract the product name from this image.The following is a product image, extract the product name from this image,",
  "The following is a product image, extract the product name from this image",
]
images = [[image1, image2], [image3]]
inputs = processor(text=prompts, images=images, padding=True, return_tensors="pt")
inputs = {k: v for k, v in inputs.items()}


# Generate
generated_ids = model.generate(**inputs, max_new_tokens=500)
generated_texts = processor.batch_decode(generated_ids, skip_special_tokens=True)

print(generated_texts)
# ['In this image, we can see the city of New York, and more specifically the Statue of Liberty. In this image, we can see the city of Chicago, and more specifically the skyscrapers of the city.', 'In which city is that bridge located? The Golden Gate Bridge is a suspension bridge spanning the Golden Gate, the one-mile-wide (1.6 km) strait connecting San Francisco Bay and the Pacific Ocean. The structure links the American city of San Francisco, California — the northern tip of the San Francisco Peninsula — to Marin County, carrying both U.S. Route 101 and California State Route 1 across the strait. The bridge is one of the most internationally recognized symbols of San Francisco, California, and the United States. It has been declared one of the Wonders of the Modern World by the American Society of Civil Engineers.\n\nThe Golden Gate Bridge is a suspension bridge spanning the Golden Gate, the one-mile-wide (1.6 km) strait connecting San Francisco Bay and the Pacific Ocean. The structure links the American city of San Francisco, California — the northern tip of the San Francisco Peninsula — to Marin County, carrying both U.S. Route 101 and California State Route 1 across the strait. The bridge is one of the most internationally recognized symbols of San Francisco, California, and the United States. It has been declared one of the Wonders of the Modern World by the American Society of Civil Engineers.\n\nThe Golden Gate Bridge is a suspension bridge spanning the Golden Gate, the one-mile-wide (1.6 km) strait connecting San Francisco Bay and the Pacific Ocean. The structure links the American city of San Francisco, California — the northern tip of the San Francisco Peninsula — to Marin County, carrying both U.S. Route 101 and California State Route 1 across the strait. The bridge is one of the most internationally recognized symbols of San Francisco, California, and the United States. It has been declared one of the Wonders of the Modern World by the American Society of Civil Engineers.\n\nThe Golden Gate Bridge is a suspension bridge spanning the Golden Gate, the one-mile-wide (1.6 km) strait connecting San Francisco Bay and the Pacific Ocean. The structure links the American city of San Francisco, California — the northern tip of the San Francisco Peninsula — to Marin County, carrying both U.S. Route 101 and California State Route 1 across the strait. The bridge is one of the most internationally recognized symbols of San Francisco, California, and']
# Out:
# /usr/local/lib/python3.10/dist-packages/transformers/generation/utils.py:2097: UserWarning: You are calling .generate() with the `input_ids` being on a device type different than your model's device. `input_ids` is on cpu, whereas the model is on cuda. You may experience unexpected behaviors or slower generation. Please make sure that you have put `input_ids` to the correct device by calling for example input_ids = input_ids.to('cuda') before running `.generate()`.
#   warnings.warn(
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-19-97066784e74c> in <cell line: 17>()
#      15
#      16 # Generate
# ---> 17 generated_ids = model.generate(**inputs, max_new_tokens=500)
#      18 generated_texts = processor.batch_decode(generated_ids, skip_special_tokens=True)
#      19
#
# /usr/local/lib/python3.10/dist-packages/torch/utils/_contextlib.py in decorate_context(*args, **kwargs)
#     114     def decorate_context(*args, **kwargs):
#     115         with ctx_factory():
# --> 116             return func(*args, **kwargs)
#     117
#     118     return decorate_context
#
# /usr/local/lib/python3.10/dist-packages/transformers/generation/utils.py in generate(self, inputs, generation_config, logits_processor, stopping_criteria, prefix_allowed_tokens_fn, synced_gpus, assistant_model, streamer, negative_prompt_ids, negative_prompt_attention_mask, **kwargs)
#    2213
#    2214             # 12. run sample (it degenerates to greedy search when `generation_config.do_sample=False`)
# -> 2215             result = self._sample(
#    2216                 input_ids,
#    2217                 logits_processor=prepared_logits_processor,
#
# /usr/local/lib/python3.10/dist-packages/transformers/generation/utils.py in _sample(self, input_ids, logits_processor, stopping_criteria, generation_config, synced_gpus, streamer, **model_kwargs)
#    3204
#    3205             # forward pass to get next token
# -> 3206             outputs = self(**model_inputs, return_dict=True)
#    3207
#    3208             # synced_gpus: don't waste resources running the code we don't need; kwargs must be updated before skipping
#
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/module.py in _wrapped_call_impl(self, *args, **kwargs)
#    1734             return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1735         else:
# -> 1736             return self._call_impl(*args, **kwargs)
#    1737
#    1738     # torchrec tests the code consistency with the following code
#
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/module.py in _call_impl(self, *args, **kwargs)
#    1745                 or _global_backward_pre_hooks or _global_backward_hooks
#    1746                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1747             return forward_call(*args, **kwargs)
#    1748
#    1749         result = None
#
# /usr/local/lib/python3.10/dist-packages/transformers/models/idefics2/modeling_idefics2.py in forward(self, input_ids, attention_mask, position_ids, past_key_values, inputs_embeds, pixel_values, pixel_attention_mask, image_hidden_states, labels, use_cache, output_attentions, output_hidden_states, return_dict, num_logits_to_keep)
#    1622
#    1623         # decoder outputs consists of (dec_features, layer_state, dec_hidden, dec_attn)
# -> 1624         outputs = self.model(
#    1625             input_ids=input_ids,
#    1626             attention_mask=attention_mask,
#
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/module.py in _wrapped_call_impl(self, *args, **kwargs)
#    1734             return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1735         else:
# -> 1736             return self._call_impl(*args, **kwargs)
#    1737
#    1738     # torchrec tests the code consistency with the following code
#
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/module.py in _call_impl(self, *args, **kwargs)
#    1745                 or _global_backward_pre_hooks or _global_backward_hooks
#    1746                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1747             return forward_call(*args, **kwargs)
#    1748
#    1749         result = None
#
# /usr/local/lib/python3.10/dist-packages/transformers/models/idefics2/modeling_idefics2.py in forward(self, input_ids, attention_mask, position_ids, past_key_values, inputs_embeds, pixel_values, pixel_attention_mask, image_hidden_states, use_cache, output_attentions, output_hidden_states, return_dict)
#    1386
#    1387         if inputs_embeds is None:
# -> 1388             inputs_embeds = self.text_model.get_input_embeddings()(input_ids)
#    1389
#    1390         # START VISUAL INPUTS INTEGRATION
#
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/module.py in _wrapped_call_impl(self, *args, **kwargs)
#    1734             return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1735         else:
# -> 1736             return self._call_impl(*args, **kwargs)
#    1737
#    1738     # torchrec tests the code consistency with the following code
#
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/module.py in _call_impl(self, *args, **kwargs)
#    1745                 or _global_backward_pre_hooks or _global_backward_hooks
#    1746                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1747             return forward_call(*args, **kwargs)
#    1748
#    1749         result = None
#
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/sparse.py in forward(self, input)
#     188
#     189     def forward(self, input: Tensor) -> Tensor:
# --> 190         return F.embedding(
#     191             input,
#     192             self.weight,
#
# /usr/local/lib/python3.10/dist-packages/torch/nn/functional.py in embedding(input, weight, padding_idx, max_norm, norm_type, scale_grad_by_freq, sparse)
#    2549         # remove once script supports set_grad_enabled
#    2550         _no_grad_embedding_renorm_(weight, input, max_norm, norm_type)
# -> 2551     return torch.embedding(weight, input, padding_idx, scale_grad_by_freq, sparse)
#    2552
#    2553
#
# RuntimeError: Expected all tensors to be on the same device, but found at least two devices, cuda:0 and cpu! (when checking argument for argument index in method wrapper_CUDA__index_select)
